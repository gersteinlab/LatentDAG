# %%
mean_list = [
    112.2863248280342, #LR
    4.409530530417978, #LASSO
#    4.6170015237682085, #SVM
#    4.3010397, #MLP
    4.6114655, #ER
    4.451412, #SF
    4.6007338, #hTFtarget
    4.624087, #TIP
    4.6397867, #GTEX
    4.4161587, #DATA
    4.6346354, #BIOGRID
    4.6699266, # STRING
    4.6382647, # combine
    4.2659683, #NOTEARS
    4.252528] #DAGMA

# %%
std_list = [
    0,
    0,
    #0,
    #0.00846203,
    0.008411996,
    0.03858556,
    0.013792022,
    0.022993892,
    0.013417222,
    0.021463444,
    0.027377125,
    0.029581694,
    0.015432803, 
    0.008131889,
    0.013105237]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, dpi=300, width_ratios=[0.2, 1.2, 0.5], gridspec_kw={"wspace":0.05}, figsize=(4,3))
ax1.barh(range(13), mean_list[::-1], xerr=std_list[::-1])
ax2.barh(range(13), mean_list[::-1], xerr=std_list[::-1])
ax3.barh(range(13), mean_list[::-1], xerr=std_list[::-1])

ax3.set_xlim(111.9, 112.4)
ax2.set_xlim(3.9, 5.1)
ax1.set_xlim(0, 0.2)

ax1.set_ylim(-1, 13)

ax3.xaxis.set_ticks([112])
ax2.xaxis.set_ticks([4, 5])
ax1.xaxis.set_ticks([0])

ax1.spines.right.set_visible(False)
ax2.spines.left.set_visible(False)
ax2.spines.right.set_visible(False)
ax3.spines.left.set_visible(False)

ax3.tick_params(axis='y', size=0)
ax2.tick_params(axis='y', size=0)

ax1.yaxis.set_ticks(range(13))
ax1.yaxis.set_ticklabels(["Linear", "Lasso", "Random-ER", "Random-SF", "ChIP-hTFtarget", "ChIP-ENCODE", "CoExp-GTEx", "CoExp-Data", "BioGRID", "STRING", "Combine", "NOTEARS", "LatentDAG"][::-1])
ax2.set_xlabel("MSE")

d = 2  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax1.plot([1, 1], [0, 1], transform=ax1.transAxes, **kwargs)
ax2.plot([0, 0], [0, 1], transform=ax2.transAxes, **kwargs)
ax2.plot([1, 1], [0, 1], transform=ax2.transAxes, **kwargs)
ax3.plot([0, 0], [0, 1], transform=ax3.transAxes, **kwargs)

ax2.vlines(4.252528, -1, 13, color='red', linestyles='dashed')

plt.savefig("./mse.pdf", dpi='figure', bbox_inches='tight')
